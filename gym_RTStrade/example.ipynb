# %%
import pandas as pd
import numpy as np

df = pd.read_csv(r'data\data_sample.csv')
df.set_index('Timestamp',inplace=True)
df_train=df[:100]
df_valid=df[100:160]
df_test=df[160:]

# %%
import gym
import gym_RTStrade

env = gym.make('Trade-v1')
env.data_init(df_train,df_valid,df_test)

obs=env.reset_to_testScore()
# Out:
# v1.11

# %%
obs=env.reset_to_testScore()
while True:          
    action=2 #buy & hold
    obs, reward, done, _ = env.step(action)
    if done:
        print('done')
        break
# Out:
# done

# %%
print('net_test: ', env.net)
# Out:
# net_test:  1150.0

# %%
pd.DataFrame(env.returns).cumsum().plot()

# %%
df_test['Close'].iloc[40:].plot()
